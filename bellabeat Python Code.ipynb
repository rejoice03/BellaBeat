# %% [markdown]
# # bellabeat

# %% [markdown]
# ## Loading Libraries
# Let's start by loading the libraries we would need for processing and visulizing the data.

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Loading Datasets

# %%
daily_activity = pd.read_csv('daily_activity.csv')
hourly_steps = pd.read_csv('hourly_steps.csv')
hourly_calories = pd.read_csv('hourly_calories.csv')
sleep_day = pd.read_csv('sleep_day.csv')
daily_calories = pd.read_csv('daily_calories.csv')
daily_intensities = pd.read_csv('daily_intensities.csv')
weight_logInfo = pd.read_csv('weight_logInfo.csv')
daily_steps = pd.read_csv('daily_steps.csv')
heartrate_seconds = pd.read_csv('heartrate_seconds.csv')

# %% [markdown]
# Pulling the first 5 rows of each datasets.

# %%
daily_activity.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
hourly_steps.head()
# Out:
#            Id           ActivityHour  StepTotal
# 0  1503960366  4/12/2016 12:00:00 AM        373
# 1  1503960366   4/12/2016 1:00:00 AM        160
# 2  1503960366   4/12/2016 2:00:00 AM        151
# 3  1503960366   4/12/2016 3:00:00 AM          0
# 4  1503960366   4/12/2016 4:00:00 AM          0

# %%
hourly_calories.head()
# Out:
#            Id           ActivityHour  Calories
# 0  1503960366  4/12/2016 12:00:00 AM        81
# 1  1503960366   4/12/2016 1:00:00 AM        61
# 2  1503960366   4/12/2016 2:00:00 AM        59
# 3  1503960366   4/12/2016 3:00:00 AM        47
# 4  1503960366   4/12/2016 4:00:00 AM        48

# %%
sleep_day.head()
# Out:
#            Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1  1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366  4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %%
daily_calories.head()
# Out:
#            Id ActivityDay  Calories
# 0  1503960366   4/12/2016      1985
# 1  1503960366   4/13/2016      1797
# 2  1503960366   4/14/2016      1776
# 3  1503960366   4/15/2016      1745
# 4  1503960366   4/16/2016      1863

# %%
daily_intensities.head()
# Out:
#            Id ActivityDay  SedentaryMinutes  LightlyActiveMinutes  \
# 0  1503960366   4/12/2016               728                   328
# 1  1503960366   4/13/2016               776                   217
# 2  1503960366   4/14/2016              1218                   181
# 3  1503960366   4/15/2016               726                   209
# 4  1503960366   4/16/2016               773                   221
#
#    FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# 0                   13                 25                      0.0
# 1                   19                 21                      0.0
# 2                   11                 30                      0.0
# 3                   34                 29                      0.0
# 4                   10                 36                      0.0
#
#    LightActiveDistance  ModeratelyActiveDistance  VeryActiveDistance
# 0                 6.06                      0.55                1.88
# ...

# %%
weight_logInfo.head()
# Out:
#            Id                   Date    WeightKg  WeightPounds   Fat  \
# 0  1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1  1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2  1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3  2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4  2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
#
#          BMI  IsManualReport          LogId
# 0  22.650000            True  1462233599000
# 1  22.650000            True  1462319999000
# 2  47.540001           False  1460509732000
# 3  21.450001            True  1461283199000
# 4  21.690001            True  1463097599000

# %%
daily_steps.head()
# Out:
#            Id ActivityDay  StepTotal
# 0  1503960366   4/12/2016      13162
# 1  1503960366   4/13/2016      10735
# 2  1503960366   4/14/2016      10460
# 3  1503960366   4/15/2016       9762
# 4  1503960366   4/16/2016      12669

# %%
heartrate_seconds.head()
# Out:
#            Id                  Time  Value
# 0  2022484408  4/12/2016 7:21:00 AM     97
# 1  2022484408  4/12/2016 7:21:05 AM    102
# 2  2022484408  4/12/2016 7:21:10 AM    105
# 3  2022484408  4/12/2016 7:21:20 AM    103
# 4  2022484408  4/12/2016 7:21:25 AM    101

# %%
print('Daily Activity:', daily_activity.columns)
print('Hourly Steps:', hourly_steps.columns)
print('hourly_calories:', hourly_calories.columns)
print('Sleep Day:', sleep_day.columns)
print('Daily Calories:', daily_calories.columns)
print('Daily Intensities:', daily_intensities.columns)
print('Weight LogInfo:', weight_logInfo.columns)
print('Daily Steps:', daily_steps.columns)
print('Heartrate Seconds:', heartrate_seconds.columns)
# Out:
# Daily Activity: Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')
# Hourly Steps: Index(['Id', 'ActivityHour', 'StepTotal'], dtype='object')
# hourly_calories: Index(['Id', 'ActivityHour', 'Calories'], dtype='object')
# Sleep Day: Index(['Id', 'SleepDay', 'TotalSleepRecords', 'TotalMinutesAsleep',
#        'TotalTimeInBed'],
#       dtype='object')
# Daily Calories: Index(['Id', 'ActivityDay', 'Calories'], dtype='object')
# Daily Intensities: Index(['Id', 'ActivityDay', 'SedentaryMinutes', 'LightlyActiveMinutes',
#        'FairlyActiveMinutes', 'VeryActiveMinutes', 'SedentaryActiveDistance',
#        'LightActiveDistance', 'ModeratelyActiveDistance',
# ...

# %% [markdown]
# Next, Let's see how many **unique users** are in each datasets.

# %%
print('Daily Activity Datasets:', daily_activity.Id.nunique(), 'unique users')
print('Hourly Steps Datasets:', hourly_steps.Id.nunique(), 'unique users')
print('Hourly Calories Datasets:', hourly_calories.Id.nunique(), 'unique users')
print('SleepDay Datasetes:', sleep_day.Id.nunique(), 'unique users')
print('Daily Calories Datasets:', daily_calories.Id.nunique(), 'unique users')
print('Daily Intensity Datasets:', daily_intensities.Id.nunique(), 'unique users')
print('Weight Logged Datasets:', weight_logInfo.Id.nunique(), 'unique users')
print('Daily Steps Datasets:', daily_steps.Id.nunique(), 'unique users')
print('Heart Rate Datasets:', heartrate_seconds.Id.nunique(), 'unique users')
# Out:
# Daily Activity Datasets: 33 unique users
# Hourly Steps Datasets: 33 unique users
# Hourly Calories Datasets: 33 unique users
# SleepDay Datasetes: 24 unique users
# Daily Calories Datasets: 33 unique users
# Daily Intensity Datasets: 33 unique users
# Weight Logged Datasets: 8 unique users
# Daily Steps Datasets: 33 unique users
# Heart Rate Datasets: 14 unique users

# %% [markdown]
# Let's view the data types in each datasets.

# %%
daily_activity.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
hourly_steps.dtypes
# Out:
# Id               int64
# ActivityHour    object
# StepTotal        int64
# dtype: object

# %%
hourly_calories.dtypes
# Out:
# Id               int64
# ActivityHour    object
# Calories         int64
# dtype: object

# %%
sleep_day.dtypes
# Out:
# Id                     int64
# SleepDay              object
# TotalSleepRecords      int64
# TotalMinutesAsleep     int64
# TotalTimeInBed         int64
# dtype: object

# %%
daily_calories.dtypes
# Out:
# Id              int64
# ActivityDay    object
# Calories        int64
# dtype: object

# %%
daily_intensities.dtypes
# Out:
# Id                            int64
# ActivityDay                  object
# SedentaryMinutes              int64
# LightlyActiveMinutes          int64
# FairlyActiveMinutes           int64
# VeryActiveMinutes             int64
# SedentaryActiveDistance     float64
# LightActiveDistance         float64
# ModeratelyActiveDistance    float64
# VeryActiveDistance          float64
# dtype: object

# %%
weight_logInfo.dtypes
# Out:
# Id                  int64
# Date               object
# WeightKg          float64
# WeightPounds      float64
# Fat               float64
# BMI               float64
# IsManualReport       bool
# LogId               int64
# dtype: object

# %%
daily_steps.dtypes
# Out:
# Id              int64
# ActivityDay    object
# StepTotal       int64
# dtype: object

# %%
heartrate_seconds.dtypes
# Out:
# Id        int64
# Time     object
# Value     int64
# dtype: object

# %% [markdown]
# let's view the shape.

# %%
print('Shape of Daily Activity:', daily_activity.shape)
print('Shape of Hourly Steps:', hourly_steps.shape)
print('Shape of Hourly Calories:', hourly_calories.shape)
print('shape of SleepDay:', sleep_day.shape)
print('Shape of Daily Calories:', daily_calories.shape)
print('Shap of Dailt Intensity:', daily_intensities.shape)
print('shape of weight Logged:', weight_logInfo.shape)
print('Shape of Daily Steps:', daily_steps.shape)
print('Shape of Heart Rate:', heartrate_seconds.shape)
# Out:
# Shape of Daily Activity: (940, 15)
# Shape of Hourly Steps: (22099, 3)
# Shape of Hourly Calories: (22099, 3)
# shape of SleepDay: (413, 5)
# Shape of Daily Calories: (940, 3)
# Shap of Dailt Intensity: (940, 10)
# shape of weight Logged: (67, 8)
# Shape of Daily Steps: (940, 3)
# Shape of Heart Rate: (2483658, 3)

# %% [markdown]
# check datasets if there are missing values, weight_logged dataset not inclusive.

# %%
print('Daily Activity Datasets has', daily_activity.isnull().values.sum(), 'missing values')
print('Hourly Steps Datasets has', hourly_steps.isnull().values.sum(), 'missing values')
print('Hourly Calories Datasets has', hourly_calories.isnull().values.sum(), 'missing values')
print('SleepDay Datasets has', sleep_day.isnull().values.sum(), 'missing values')
print('Daily Calories Datasets has', daily_calories.isnull().values.sum(), 'missing values')
print('Daily Instensity Datasets has', daily_intensities.isnull().values.sum(), 'missing values')
print('Daily Steps Datasets has', daily_steps.isnull().values.sum(), 'missing values')
print('Hearte Rate Datasets has', heartrate_seconds.isnull().values.sum(), 'missing values')
# Out:
# Daily Activity Datasets has 0 missing values
# Hourly Steps Datasets has 0 missing values
# Hourly Calories Datasets has 0 missing values
# SleepDay Datasets has 0 missing values
# Daily Calories Datasets has 0 missing values
# Daily Instensity Datasets has 0 missing values
# Daily Steps Datasets has 0 missing values
# Hearte Rate Datasets has 0 missing values

# %% [markdown]
# Check for duplicates.

# %%
print('Duplicates in Daily Activity:', daily_activity.duplicated().head())
print('Duplicates in Hourly Steps:', hourly_steps.duplicated().head())
print('Duplicates in Hourly Calories:', hourly_calories.duplicated().head())
print('Duplicates in SleepDay:', sleep_day.duplicated().head())
print('Duplicates in Daily Calories:', daily_calories.duplicated().head())
print('Duplicates in Daily Intensity:', daily_intensities.duplicated().head())
print('Duplicates in Daily Steps:', daily_steps.duplicated().head())
print('Duplicates in Heart Rate:', heartrate_seconds.duplicated().head())
# Out:
# Duplicates in Daily Activity: 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# Duplicates in Hourly Steps: 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# Duplicates in Hourly Calories: 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# Duplicates in SleepDay: 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# Duplicates in Daily Calories: 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# Duplicates in Daily Intensity: 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# Duplicates in Daily Steps: 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# Duplicates in Heart Rate: 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# Converthing the **"Activity"** in daily_activity, **"ActivityHour"** in hourly_steps, **"ActivityHour"** in hourly_calories, and **"SleepDay"** in sleepday to datetime data type.

# %%
daily_activity['ActivityDate'] = pd.to_datetime(daily_activity['ActivityDate'])
hourly_steps['ActivityHour'] = pd.to_datetime(hourly_steps['ActivityHour'])
hourly_calories['ActivityHour'] = pd.to_datetime(hourly_calories['ActivityHour'])
sleep_day['SleepDay'] = pd.to_datetime(sleep_day['SleepDay'])

# %% [markdown]
# let's Check for Changes.

# %%
print('Daily Activity Data type is', daily_activity['ActivityDate'].dtype, 'data type')
print('Hourly Steps data type is', hourly_steps['ActivityHour'].dtype, 'data type')
print('Hourly Calories data type is', hourly_calories['ActivityHour'].dtype, 'data type')
print('SleepDay data type is', sleep_day['SleepDay'].dtype, 'data type')
# Out:
# Daily Activity Data type is datetime64[ns] data type
# Hourly Steps data type is datetime64[ns] data type
# Hourly Calories data type is datetime64[ns] data type
# SleepDay data type is datetime64[ns] data type

# %% [markdown]
# Merge hourly_steps with hourly_calories datasets.

# %%
for col in hourly_steps.columns, hourly_calories.columns:
    print(col)
# Out:
# Index(['Id', 'ActivityHour', 'StepTotal'], dtype='object')
# Index(['Id', 'ActivityHour', 'Calories'], dtype='object')

# %%
merge_df = pd.merge(hourly_steps, hourly_calories,
                   on = ['Id', 'ActivityHour'], how = 'inner')
merge_df.head()
# Out:
#            Id        ActivityHour  StepTotal  Calories
# 0  1503960366 2016-04-12 00:00:00        373        81
# 1  1503960366 2016-04-12 01:00:00        160        61
# 2  1503960366 2016-04-12 02:00:00        151        59
# 3  1503960366 2016-04-12 03:00:00          0        47
# 4  1503960366 2016-04-12 04:00:00          0        48

# %% [markdown]
# Create new column name 'WeekDay'.

# %%
daily_activity['WeekDay'] = daily_activity['ActivityDate'].dt.day_name()
merge_df['WeekDay'] = merge_df['ActivityHour'].dt.day_name()
sleep_day['WeekDay'] = sleep_day['SleepDay'].dt.day_name()

# %%
# View changes
daily_activity.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-04-12       13162           8.50             8.50
# 1  1503960366   2016-04-13       10735           6.97             6.97
# 2  1503960366   2016-04-14       10460           6.74             6.74
# 3  1503960366   2016-04-15        9762           6.28             6.28
# 4  1503960366   2016-04-16       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
merge_df.head()
# Out:
#            Id        ActivityHour  StepTotal  Calories  WeekDay
# 0  1503960366 2016-04-12 00:00:00        373        81  Tuesday
# 1  1503960366 2016-04-12 01:00:00        160        61  Tuesday
# 2  1503960366 2016-04-12 02:00:00        151        59  Tuesday
# 3  1503960366 2016-04-12 03:00:00          0        47  Tuesday
# 4  1503960366 2016-04-12 04:00:00          0        48  Tuesday

# %%
sleep_day.head()
# Out:
#            Id   SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366 2016-04-12                  1                 327
# 1  1503960366 2016-04-13                  2                 384
# 2  1503960366 2016-04-15                  1                 412
# 3  1503960366 2016-04-16                  2                 340
# 4  1503960366 2016-04-17                  1                 700
#
#    TotalTimeInBed    WeekDay
# 0             346    Tuesday
# 1             407  Wednesday
# 2             442     Friday
# 3             367   Saturday
# 4             712     Sunday

# %% [markdown]
# Need to extract the ActivityHour column by creating a separate column for it.

# %%
merge_df['DateHour'] = merge_df['ActivityHour'].dt.hour
merge_df.head()
# Out:
#            Id        ActivityHour  StepTotal  Calories  WeekDay  DateHour
# 0  1503960366 2016-04-12 00:00:00        373        81  Tuesday         0
# 1  1503960366 2016-04-12 01:00:00        160        61  Tuesday         1
# 2  1503960366 2016-04-12 02:00:00        151        59  Tuesday         2
# 3  1503960366 2016-04-12 03:00:00          0        47  Tuesday         3
# 4  1503960366 2016-04-12 04:00:00          0        48  Tuesday         4

# %% [markdown]
# Let's remove the hour min, sec and create ActivityDay from merge_df.

# %%
merge_df['ActivityDay'] = merge_df['ActivityHour'].dt.date
merge_df.head()
# Out:
#            Id        ActivityHour  StepTotal  Calories  WeekDay  DateHour  \
# 0  1503960366 2016-04-12 00:00:00        373        81  Tuesday         0
# 1  1503960366 2016-04-12 01:00:00        160        61  Tuesday         1
# 2  1503960366 2016-04-12 02:00:00        151        59  Tuesday         2
# 3  1503960366 2016-04-12 03:00:00          0        47  Tuesday         3
# 4  1503960366 2016-04-12 04:00:00          0        48  Tuesday         4
#
#   ActivityDay
# 0  2016-04-12
# 1  2016-04-12
# 2  2016-04-12
# 3  2016-04-12
# 4  2016-04-12

# %% [markdown]
# Now drop ActivityHour column from merge_df.

# %%
merge_df = merge_df.drop('ActivityHour', axis = 1)
merge_df.head()
# Out:
#            Id  StepTotal  Calories  WeekDay  DateHour ActivityDay
# 0  1503960366        373        81  Tuesday         0  2016-04-12
# 1  1503960366        160        61  Tuesday         1  2016-04-12
# 2  1503960366        151        59  Tuesday         2  2016-04-12
# 3  1503960366          0        47  Tuesday         3  2016-04-12
# 4  1503960366          0        48  Tuesday         4  2016-04-12

# %% [markdown]
# ActivityDay data type is object we need to change ActivityDay to Datetime.

# %%
merge_df['ActivityDay'] = pd.to_datetime(merge_df['ActivityDay'])

# %% [markdown]
# Next, we're going to merge "sleepday" with "merge_df" to create a new dataframe that contains sleepday record with calories for some analysis. Hence, before we do, let's change the column name "SleepDay" in sleepday df, so it matches "ActivityDay" in "merge_df".

# %%
sleep_day = sleep_day.rename(columns={'SleepDay':'ActivityDay'})
sleep_day.head()
# Out:
#            Id ActivityDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  2016-04-12                  1                 327
# 1  1503960366  2016-04-13                  2                 384
# 2  1503960366  2016-04-15                  1                 412
# 3  1503960366  2016-04-16                  2                 340
# 4  1503960366  2016-04-17                  1                 700
#
#    TotalTimeInBed    WeekDay
# 0             346    Tuesday
# 1             407  Wednesday
# 2             442     Friday
# 3             367   Saturday
# 4             712     Sunday

# %% [markdown]
# Merge "sleepday" with "merge_df". But first need to check columns they share in common.

# %%
for col in merge_df.columns, sleep_day.columns:
    print(col)
# Out:
# Index(['Id', 'StepTotal', 'Calories', 'WeekDay', 'DateHour', 'ActivityDay'], dtype='object')
# Index(['Id', 'ActivityDay', 'TotalSleepRecords', 'TotalMinutesAsleep',
#        'TotalTimeInBed', 'WeekDay'],
#       dtype='object')

# %% [markdown]
# ID, ActivityDay and Weekday are common in two dataframe. let's merge merge_df and sleepday.

# %%
merge_df2 = pd.merge(merge_df, sleep_day,
                    on = ['Id', 'ActivityDay', 'WeekDay'], how = 'inner')
merge_df2.head()
# Out:
#            Id  StepTotal  Calories  WeekDay  DateHour ActivityDay  \
# 0  1503960366        373        81  Tuesday         0  2016-04-12
# 1  1503960366        160        61  Tuesday         1  2016-04-12
# 2  1503960366        151        59  Tuesday         2  2016-04-12
# 3  1503960366          0        47  Tuesday         3  2016-04-12
# 4  1503960366          0        48  Tuesday         4  2016-04-12
#
#    TotalSleepRecords  TotalMinutesAsleep  TotalTimeInBed
# 0                  1                 327             346
# 1                  1                 327             346
# 2                  1                 327             346
# 3                  1                 327             346
# 4                  1                 327             346

# %%
merge_df2.tail()
# Out:
#               Id  StepTotal  Calories    WeekDay  DateHour ActivityDay  \
# 9766  8792009665          8        74  Wednesday        19  2016-05-04
# 9767  8792009665        132        91  Wednesday        20  2016-05-04
# 9768  8792009665          0        71  Wednesday        21  2016-05-04
# 9769  8792009665          0        70  Wednesday        22  2016-05-04
# 9770  8792009665          0        70  Wednesday        23  2016-05-04
#
#       TotalSleepRecords  TotalMinutesAsleep  TotalTimeInBed
# 9766                  1                 439             463
# 9767                  1                 439             463
# 9768                  1                 439             463
# 9769                  1                 439             463
# 9770                  1                 439             463

# %% [markdown]
# Let's see how many unique and missing values.

# %%
print('Merge_df2 Dataframe has:', merge_df2.Id.nunique(), 'unique users')
print('Merge_df2 DataFrame has', merge_df2.isnull().values.sum(), 'missing values')
# Out:
# Merge_df2 Dataframe has: 24 unique users
# Merge_df2 DataFrame has 0 missing values

# %% [markdown]
# Let's also make some changes to the dail_activity dataframe. Then creating 3 additional columns "TotalActiveMinutes", "TotalMinutes", and "TotalActiveHours". After we'll remove columns we won't need.

# %%
new_cols = ['Id', 'ActivityDate',
            'WeekDay', 'TotalSteps',
            'TotalDistance', 'VeryActiveDistance',
           'ModeratelyActiveDistance', 'LightActiveDistance',
           'SedentaryActiveDistance', 'VeryActiveMinutes',
           'FairlyActiveMinutes', 'LightlyActiveMinutes',
           'SedentaryMinutes', 'TotalActiveMinutes',
           'TotalMinutes', 'TotalActiveHours', 'Calories']
daily_activity = daily_activity.reindex(columns=new_cols)

# %%
# Let's view the changes.
daily_activity[['TotalActiveMinutes',
               'TotalMinutes', 'TotalActiveHours']].head()
# Out:
#    TotalActiveMinutes  TotalMinutes  TotalActiveHours
# 0                 NaN           NaN               NaN
# 1                 NaN           NaN               NaN
# 2                 NaN           NaN               NaN
# 3                 NaN           NaN               NaN
# 4                 NaN           NaN               NaN

# %%
daily_activity['TotalActiveMinutes'] = daily_activity['VeryActiveMinutes'] + daily_activity['FairlyActiveMinutes'] + daily_activity['LightlyActiveMinutes']
daily_activity['TotalMinutes'] = daily_activity['TotalActiveMinutes'] + daily_activity['SedentaryMinutes']
daily_activity['TotalActiveHours'] = round(daily_activity['TotalActiveMinutes'] / 60)

# %%
daily_activity[['TotalActiveMinutes', 'TotalMinutes', 'TotalActiveHours']].head()
# Out:
#    TotalActiveMinutes  TotalMinutes  TotalActiveHours
# 0                 366          1094               6.0
# 1                 257          1033               4.0
# 2                 222          1440               4.0
# 3                 272           998               5.0
# 4                 267          1040               4.0

# %%
daily_activity.head()
# Out:
#            Id ActivityDate    WeekDay  TotalSteps  TotalDistance  \
# 0  1503960366   2016-04-12    Tuesday       13162           8.50
# 1  1503960366   2016-04-13  Wednesday       10735           6.97
# 2  1503960366   2016-04-14   Thursday       10460           6.74
# 3  1503960366   2016-04-15     Friday        9762           6.28
# 4  1503960366   2016-04-16   Saturday       12669           8.16
#
#    VeryActiveDistance  ModeratelyActiveDistance  LightActiveDistance  \
# 0                1.88                      0.55                 6.06
# 1                1.57                      0.69                 4.71
# 2                2.44                      0.40                 3.91
# 3                2.14                      1.26                 2.83
# 4                2.71                      0.41                 5.04
#
#    SedentaryActiveDistance  VeryActiveMinutes  FairlyActiveMinutes  \
# 0                      0.0                 25                   13
# ...

# %% [markdown]
# Now that our data is processed,it's time to analyze it for insights. We have narrowed down our datasets to 3 dataframes:
# - daily_activity
# - merge_df, and
# - merge_df2
#
# So, we're going to draw our insights from these dataframes. Let's start by getting some statistical info about them.

# %%
daily_activity.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  VeryActiveDistance  \
# count  9.400000e+02    940.000000     940.000000          940.000000
# mean   4.855407e+09   7637.910638       5.489702            1.502681
# std    2.424805e+09   5087.150742       3.924606            2.658941
# min    1.503960e+09      0.000000       0.000000            0.000000
# 25%    2.320127e+09   3789.750000       2.620000            0.000000
# 50%    4.445115e+09   7405.500000       5.245000            0.210000
# 75%    6.962181e+09  10727.000000       7.712500            2.052500
# max    8.877689e+09  36019.000000      28.030001           21.920000
#
#        ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# count                940.000000           940.000000               940.000000
# mean                   0.567543             3.340819                 0.001606
# std                    0.883580             2.040655                 0.007346
# ...

# %%
merge_df.describe()
# Out:
#                  Id     StepTotal      Calories      DateHour
# count  2.209900e+04  22099.000000  22099.000000  22099.000000
# mean   4.848235e+09    320.166342     97.386760     11.415765
# std    2.422500e+09    690.384228     60.702622      6.915140
# min    1.503960e+09      0.000000     42.000000      0.000000
# 25%    2.320127e+09      0.000000     63.000000      5.000000
# 50%    4.445115e+09     40.000000     83.000000     11.000000
# 75%    6.962181e+09    357.000000    108.000000     17.000000
# max    8.877689e+09  10554.000000    948.000000     23.000000

# %%
merge_df2.describe()
# Out:
#                  Id    StepTotal     Calories     DateHour  TotalSleepRecords  \
# count  9.771000e+03  9771.000000  9771.000000  9771.000000        9771.000000
# mean   5.000942e+09   358.765838   100.978917    11.422884           1.120356
# std    2.061194e+09   652.628865    63.440338     6.921320           0.347304
# min    1.503960e+09     0.000000    42.000000     0.000000           1.000000
# 25%    3.977334e+09     0.000000    63.000000     5.000000           1.000000
# 50%    4.702922e+09   107.000000    84.000000    11.000000           1.000000
# 75%    6.962181e+09   420.000000   117.000000    17.000000           1.000000
# max    8.792010e+09  6357.000000   669.000000    23.000000           3.000000
#
#        TotalMinutesAsleep  TotalTimeInBed
# count         9771.000000     9771.000000
# mean           419.350322      458.607921
# std            118.789342      127.597596
# min             58.000000       61.000000
# 25%            361.000000      402.000000
# ...

# %% [markdown]
# ## Data Visuatization

# %% [markdown]
# The correlation between TotalDistance, TotalSteps, SedentaryMinutes, TotalActiveMinutes, Calories.

# %%
corr1 = ['TotalDistance', 'TotalSteps', 'SedentaryMinutes', 'TotalActiveMinutes', 'Calories']
fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.heatmap(daily_activity[corr1].corr(),
            annot = True,
            fmt = '.2f',
            linewidths=0.5,
            cmap='icefire')
ax.set_title('Correlation Matrix');

# %% [markdown]
# Comparing Total steps and sedentary minutes to calories.

# %%
fig, (ax0, ax1) = plt.subplots(nrows = 2,
                               ncols = 1,
                               figsize = (10, 10),
                               sharex = True)

scatter = ax0.scatter(x = daily_activity['Calories'],
                      y = daily_activity['TotalSteps'],
                      color = '#fd8f7a')

ax0.set(title = 'Calories Burnt By Total Steps',
        ylabel = 'TotalSteps')

ax0.legend(*scatter.legend_elements(), title = None)
scatter = ax1.scatter(x = daily_activity['Calories'],
                      y = daily_activity['SedentaryMinutes'],
                      color = '#fd8f7a')

ax1.set(title = 'Sedentary Minutes and Calories',
        ylabel = 'Sedentary Minutes')

ax1.legend(*scatter.legend_elements(), title = None);
# Out:
# C:\Users\rejoi\anaconda3\lib\site-packages\matplotlib\collections.py:1098: UserWarning: Collection without array used. Make sure to specify the values to be colormapped via the `c` argument.
#   warnings.warn("Collection without array used. Make sure to "

# %% [markdown]
# Sedentary Minutes vs Total Active Minutes.

# %%
fig, ax = plt.subplots(figsize = (8, 5))
x = np.array(['Sedentary Minutes', 'Total Active Minutes'])
y = np.array([daily_activity['SedentaryMinutes'].mean(),
             daily_activity['TotalActiveMinutes'].mean()])

plt.title('Sedentary Minutes vs Total Active Minutes')
plt.bar(x, y, width = 0.8, color = '#fd8f7a')
plt.show()

# %% [markdown]
# Total Calories Burnt by Day of the Week.

# %%
fig, ax = plt.subplots(figsize = (10, 5))
plt.bar(merge_df.WeekDay, merge_df.Calories, color = '#fd8f7a')
plt.xlabel('Week Day')
plt.ylabel('Calories Burned')
plt.title('CAlories Burned by Day of the Week')
plt.grid()
plt.show()

# %% [markdown]
# Total Steps by Day of the Week.

# %%
fig, ax = plt.subplots(figsize = (10, 5))
plt.bar(daily_activity.WeekDay, daily_activity.TotalSteps, color = '#fd8f7a')
plt.xlabel('Week Day')
plt.ylabel('Total Steps Taken')
plt.title('Total Steps Taken by Day of the Week')
plt.grid()
plt.show()

# %% [markdown]
# Total Time Asleep by Day of the Week.

# %%
fig, ax = plt.subplots(figsize = (10, 5))
x = merge_df2['WeekDay']
y = merge_df2['TotalMinutesAsleep']
plt.title('Total Time Asleep by Day of the Week')
plt.bar(x, y, width = 0.8, color = '#fd8f7a')
plt.show()

# %% [markdown]
# The most and least active hours of the day.

# %%
# Least active time of the day for trageted ads
fig, axs = plt.subplots(figsize = (10, 6))
merge_df.groupby(merge_df['DateHour'])['StepTotal'].mean().plot(kind = 'bar',
                                                               rot = 0, ax = axs,
                                                               color = '#fd8f7a',
                                                               title = 'The most and active hours of the day')
plt.xlabel('Hour of the Day')
plt.ylabel('Total Steps')
plt.show()
